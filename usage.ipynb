# %%
cd /mnt/data/kaiwork/opt_kai/
# Out:
# /mnt/data/kaiwork/opt_kai

# %%
from Optimizer import *

# %%
stocks = pd.read_csv("./input_format.csv")
stocks
# Out:
#       Symbol       Max  tcost    scores  weights_ystd       sect  \
# 0          1  0.012000  0.005  0.000579      0.002997  801780.SI
# 1          6  0.002113  0.000  0.000741      0.000000  801180.SI
# 2          9  0.012000  0.000  0.000647      0.004108  801230.SI
# 3         11  0.005410  0.000  0.000729      0.001988  801180.SI
# 4         12  0.003077  0.000  0.000688      0.000000  801710.SI
# ...      ...       ...    ...       ...           ...        ...
# 1584  603987  0.012000  0.000 -0.000236      0.000000  801150.SI
# 1585  603988  0.009147  0.000 -0.001263      0.000000  801730.SI
# 1586  603989  0.002550  0.000  0.001346      0.003006  801080.SI
# 1587  603990  0.003330  0.000  0.000518      0.000000  801750.SI
# 1588  603997  0.003156  0.000 -0.000645      0.000000  801880.SI
#
#                 mv     trend
# 0     2.525465e+11  0.000000
# 1     6.458395e+09 -0.053852
# 2     1.715055e+10  0.064309
# 3     4.729856e+09 -0.096558
# 4     8.967246e+09  0.000000
# ...            ...       ...
# 1584  6.594106e+09  0.003060
# 1585  2.890608e+09  0.000000
# 1586  1.070018e+10  0.000000
# 1587  5.126016e+09  0.114214
# 1588  4.300002e+09 -0.058476
#
# [1589 rows x 8 columns]

# %%
# prepare Portfolio object 
pool = Portfolio(stocks)

# and constrains
foldpath, date = "/mnt/shared/public/for_kai/", "20200601"
sect_cond_path = os.path.join(foldpath, "condition", date, "level_Sect.csv")
sect_constrains = (pd.read_csv(sect_cond_path).set_index("SectID")["Weight"]/100).round(5).to_dict()

rules = {"stock_num":200,                      # pick exact 200 stocks
         "tcost":0.005 * 1,                    # tcost 
         "section":[sect_constrains, 0.01],    # expect value, tolerance
         "mv":[0.35, 0.02],                    # expect value, tolerance
         "trend":[0.05, 0.01]}                 # expect value, tolerance

# %%
solver = Solver(pool, rules=rules)
# %time solver.solve()
# Out:
# Status: Optimal
# CPU times: user 2.29 s, sys: 21.7 ms, total: 2.31 s
# Wall time: 16.5 s

# %%
solver.evaluate()
# Out:
# [Before Adjust] Score: 0.000562    Percentile: 0.2454
# [~After Adjust] Score: 0.001084    Percentile: 0.0554
#
# >> Turnover:
#  Buy in 0.294967   Adjust 0.1216
#
# >> Market Value:
#  Before 0.318145   After 0.3428   Target 0.3500   Δ -0.0072
#
# >> Trend:
#  Before 0.052588   After 0.0455   Target 0.0500   Δ -0.0045
#
# Section exposure:
#
#               before     after   target         Δ
# sect
# 801150.SI  0.120030  0.132495  0.12211  0.010385
# 801080.SI  0.112350  0.112314  0.11728 -0.004966
# 801750.SI  0.091726  0.081164  0.08575 -0.004586
# 801030.SI  0.064217  0.071408  0.07318 -0.001772
# 801760.SI  0.047133  0.043548  0.05414 -0.010592
# 801050.SI  0.038847  0.032987  0.03530 -0.002313
# 801790.SI  0.038634  0.030850  0.03734 -0.006490
# 801730.SI  0.038613  0.045153  0.04547 -0.000317
# 801180.SI  0.035906  0.034154  0.03521 -0.001056
# 801890.SI  0.035594  0.033851  0.03399 -0.000139
# 801740.SI  0.034448  0.041085  0.03114  0.009945
# 801170.SI  0.033628  0.034227  0.03111  0.003117
# 801040.SI  0.033282  0.028766  0.02925 -0.000484
# 801880.SI  0.032307  0.031360  0.03004  0.001320
# 801010.SI  0.030959  0.031300  0.02874  0.002560
# 801160.SI  0.029650  0.033356  0.03180  0.001556
# 801770.SI  0.025387  0.020079  0.02498 -0.004901
# 801200.SI  0.022971  0.018776  0.02710 -0.008324
# 801120.SI  0.021875  0.034982  0.02691  0.008072
# 801710.SI  0.020979  0.020718  0.01805  0.002668
# 801140.SI  0.015623  0.010944  0.01778 -0.006836
# 801720.SI  0.013287  0.006810  0.01180 -0.004990
# 801780.SI  0.013109  0.018856  0.01153  0.007326
# 801230.SI  0.012069  0.024543  0.01299  0.011553
# 801020.SI  0.010610  0.007483  0.01137 -0.003887
# 801110.SI  0.008991  0.012623  0.00776  0.004863
# 801210.SI  0.005994  0.003704  0.00514 -0.001436
# 801130.SI  0.002997  0.002464  0.00277 -0.000306
#
#
# New buy in:
#
#   001152   0% -> 0.62%      |     000258   0% -> 0.36%      |     001155   0% -> 0.33%
#   000132   0% -> 0.70%      |     000007   0% -> 0.32%      |     001546   0% -> 0.63%
#   000908   0% -> 0.61%      |     000019   0% -> 0.35%      |     000275   0% -> 1.14%
#   001049   0% -> 0.62%      |     000921   0% -> 0.70%      |     000671   0% -> 0.71% *
#   001059   0% -> 0.81%      |     000292   0% -> 0.40%      |     001445   0% -> 0.71%
#   000425   0% -> 0.36%      |     000693   0% -> 1.24%      |     000826   0% -> 0.57%
#   001466   0% -> 0.62%      |     000701   0% -> 1.24%      |     000189   0% -> 0.30%
#   000704   0% -> 0.75%      |     001344   0% -> 0.60%      |     001475   0% -> 0.64%
#   000196   0% -> 0.41%      |     000197   0% -> 0.89%      |     000582   0% -> 0.58%
#   000839   0% -> 0.56%      |     001482   0% -> 0.37%      |     000332   0% -> 0.37%
#   001101   0% -> 0.63%      |     000846   0% -> 0.43%      |     000082   0% -> 1.31%
#   000214   0% -> 0.59%      |     000606   0% -> 0.57%      |     001378   0% -> 0.49%
#   000739   0% -> 0.48%      |     001003   0% -> 0.88%      |     001261   0% -> 1.20%
#   001517   0% -> 0.73%      |     000381   0% -> 0.57% *    |     000505   0% -> 1.20% *
#   000637   0% -> 0.87%      |     001150   0% -> 0.37%      |     001279   0% -> 0.69%
#
#
# Sell:
#
#   000002   0.41% -> 0%      |     000515   0.50% -> 0%      |     000643   0.39% -> 0%
#   000386   0.40% -> 0%      |     000905   0.69% -> 0%      |     000266   0.68% -> 0%
#   000017   0.24% -> 0%      |     001297   0.76% -> 0%      |     000916   0.65% -> 0%
#   001559   0.81% -> 0%      |     000920   0.58% -> 0%      |     001309   0.26% -> 0%
#   000670   0.30% -> 0%      |     001439   0.93% -> 0%      |     000161   0.50% -> 0%
#   000929   0.65% -> 0%      |     001571   0.44% -> 0%      |     001533   0.40% -> 0%
#   001326   0.31% -> 0%      |     000307   0.30% -> 0%      |     000436   1.00% -> 0%
#   000182   0.50% -> 0%      |     000313   0.50% -> 0%      |     001338   0.30% -> 0%
#   000447   0.38% -> 0%      |     001474   0.36% -> 0%      |     000837   0.50% -> 0%
#   001094   0.69% -> 0%      |     000453   0.40% -> 0%      |     000457   0.40% -> 0%
#   000331   0.30% -> 0%      |     001483   0.38% -> 0%      |     000337   0.73% -> 0%
#   000979   0.30% -> 0%      |     001239   0.30% -> 0%      |     000092   0.66% -> 0%
#   001505   0.71% -> 0%      |     001379   0.30% -> 0%      |     001124   0.32% -> 0%
#   000230   0.37% -> 0%      |     000742   0.39% -> 0%      |     001382   0.40% -> 0%
#   000998   0.40% -> 0%      |     001135   1.06% -> 0%      |     000115   0.30% -> 0%
#   000508   0.72% -> 0%      |     001277   0.50% -> 0%      |     000767   0.40% -> 0%
#
#
# Adjust:
#
#   000000   0.30% -> 0.39%    |   001024   0.39% -> 0.63%    |   000003   0.20% -> 0.47%
#   001540   0.39% -> 0.35%    |   001030   0.95% -> 0.35%    |   000006   0.38% -> 0.47%
#   001552   0.30% -> 0.25%    |   001560   0.72% -> 0.49%    |   000029   0.38% -> 0.54%
#   000030   0.34% -> 0.48%    |   000543   0.17% -> 0.16%    |   001568   0.40% -> 0.62%
#   001570   0.40% -> 0.38%    |   001060   0.82% -> 0.78%    |   000037   0.23% -> 0.19%
#   001062   0.35% -> 0.74%    |   001063   0.58% -> 0.51%    |   000550   0.40% -> 0.37%
#   000551   0.34% -> 0.35%    |   000556   0.71% -> 0.60%    |   001071   0.43% -> 0.20%
#   001586   0.30% -> 0.26%    |   001086   0.24% -> 0.21%    |   000071   0.85% -> 1.06%
#   000072   0.29% -> 0.20%    |   000084   0.40% -> 0.44%    |   000089   0.30% -> 0.44%
#   001115   1.02% -> 0.21%    |   000096   0.49% -> 0.50%    |   000610   0.40% -> 0.48%
#   000101   0.41% -> 0.21%    |   000615   0.39% -> 0.94%    |   000104   0.50% -> 0.54%
#   001132   0.68% -> 0.47%    |   000621   0.40% -> 0.22%    |   001142   0.72% -> 0.45%
#   000633   0.72% -> 0.29%    |   000638   0.40% -> 0.56%    |   001156   0.30% -> 0.29%
#   000646   0.39% -> 0.52%    |   000648   0.38% -> 0.39%    |   000661   0.40% -> 0.54%
#   000150   0.38% -> 0.43%    |   000153   0.40% -> 0.70%    |   001180   0.33% -> 0.28%
#   000158   0.39% -> 0.59%    |   000177   0.98% -> 0.90%    |   001207   0.30% -> 0.78%
#   000183   0.40% -> 0.40%    |   001211   0.34% -> 0.63%    |   000703   0.30% -> 0.37%
#   000202   0.32% -> 0.25%    |   001227   0.43% -> 0.43%    |   000204   0.72% -> 0.32%
#   001234   0.45% -> 0.17%    |   000725   0.34% -> 1.00%    |   000215   0.30% -> 0.76%
#   001245   0.40% -> 0.59%    |   000223   0.40% -> 0.65%    |   000741   0.40% -> 0.56%
#   001257   1.02% -> 0.73%    |   000234   0.34% -> 0.51%    |   000238   0.46% -> 0.63%
#   000239   0.34% -> 0.69%    |   001264   0.68% -> 0.51%    |   000245   0.39% -> 0.38%
#   001270   0.49% -> 0.43%    |   000251   0.46% -> 0.48%    |   001275   0.53% -> 0.47%
#   001278   0.40% -> 0.39%    |   000254   0.59% -> 0.67%    |   000256   0.40% -> 0.31%
#   000769   0.59% -> 0.45%    |   001283   0.30% -> 0.58%    |   000260   0.30% -> 0.40%
#   000261   0.40% -> 0.58%    |   000782   0.40% -> 0.42%    |   000271   0.39% -> 0.52%
#   000784   0.70% -> 0.55%    |   000276   0.44% -> 0.53%    |   000792   1.01% -> 0.37%
#   000796   0.99% -> 0.66%    |   001311   0.41% -> 0.47%    |   001313   1.12% -> 0.51%
#   001315   0.44% -> 0.38%    |   000805   0.28% -> 0.23%    |   000295   0.34% -> 0.58%
#   000297   0.40% -> 0.19%    |   000300   1.01% -> 0.57%    |   001328   0.66% -> 0.26%
#   000820   0.38% -> 0.24%    |   001336   0.41% -> 0.21%    |   000314   0.30% -> 0.50%
#   000316   0.27% -> 0.24%    |   000828   0.99% -> 0.49%    |   000319   0.41% -> 0.66%
#   001356   0.22% -> 0.17%    |   001360   0.75% -> 0.43%    |   000852   0.17% -> 0.17%
#   001366   0.91% -> 1.22%    |   000860   0.35% -> 0.25%    |   001377   0.81% -> 0.44%
#   000358   0.43% -> 0.28%    |   000872   0.33% -> 0.37%    |   000363   0.69% -> 0.59%
#   001390   0.32% -> 0.29%    |   000370   0.40% -> 0.32%    |   001395   0.18% -> 0.14%
#   001397   0.98% -> 0.43%    |   001400   0.37% -> 0.36%    |   000889   0.38% -> 0.42%
#   000893   0.31% -> 0.27%    |   000383   0.70% -> 0.19%    |   001416   0.27% -> 0.17%
#   000912   0.39% -> 0.82%    |   000915   0.70% -> 0.36%    |   001428   0.99% -> 0.37%
#   000405   0.40% -> 0.38%    |   000918   0.41% -> 0.51%    |   000412   1.02% -> 0.24%
#   001443   0.39% -> 0.30%    |   000936   0.39% -> 0.45%    |   000428   0.21% -> 0.29%
#   001458   0.40% -> 0.61%    |   001459   0.83% -> 0.81%    |   000946   0.34% -> 0.54%
#   000439   1.13% -> 0.42%    |   000961   0.30% -> 0.53%    |   000963   0.40% -> 0.47%
#   000452   0.70% -> 0.46%    |   000456   0.39% -> 0.40%    |   000969   0.30% -> 0.62%
#   000972   0.40% -> 0.30%    |   001488   0.42% -> 0.79%    |   000977   0.40% -> 0.45%
#   000466   0.44% -> 0.31%    |   001491   0.40% -> 0.75%    |   001492   0.69% -> 0.51%
#   001493   0.30% -> 0.39%    |   001494   0.39% -> 0.36%    |   000980   0.40% -> 0.50%
#   001496   0.39% -> 0.53%    |   000472   0.39% -> 0.37%    |   000478   0.39% -> 0.53%
#   000995   1.02% -> 0.66%    |   001509   0.40% -> 0.35%    |   001001   0.37% -> 0.34%
#   001518   0.35% -> 0.25%    |   001523   0.58% -> 0.44%    |   000502   0.71% -> 0.24%
#   001016   0.99% -> 0.40%    |   001017   0.30% -> 0.59%    |   001019   0.70% -> 0.55%
#   001532   0.60% -> 0.45%    |   001023   0.30% -> 0.26%    |
